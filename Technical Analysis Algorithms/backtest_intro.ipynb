# %% [markdown]
# # Backtesting Intro
#
# This notebook is just to experiment with the backtesting.py library and backtrader.py

# %%
import yfinance as yf
import talib
import pandas as pd
import numpy as np
from backtesting import Backtest, Strategy
import sambo
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First strategy using Backtest Strategy Class. Super basic EMA Crossover. Just to see how it performs in a backtest

# %%
#DEFINING THE STRATEGY

class EMACrossoverFuturesStrategy(Strategy):
    short_period = 12
    long_period = 26
    point_tp = 20
    point_sl = 10

    def init(self):
        close = self.data.Close
        self.short_ema = self.I(talib.EMA, close, self.short_period)
        self.long_ema = self.I(talib.EMA, close, self.long_period)

    def next(self):
        price = self.data.Close[-1]

        crossover_up = self.short_ema[-2] < self.long_ema[-2] and self.short_ema[-1] > self.long_ema[-1]
        crossover_down = self.short_ema[-2] > self.long_ema[-2] and self.short_ema[-1] < self.long_ema[-1]

        try:
            if crossover_up and not self.position.is_long:
                sl = price - self.point_sl
                tp = price + self.point_tp
                self.buy(size=1, sl=sl, tp=tp)

            elif crossover_down and not self.position.is_short:
                sl = price + self.point_sl
                tp = price - self.point_tp
                self.sell(size=1, sl=sl, tp=tp)

        except Exception as e:
            print(f"Trade error: {e}")

# %%
nqdata = yf.download('NQ=F', start='2025-03-10', end='2025-03-11', interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
nqdata.columns = [col[0] if isinstance(col, tuple) else col for col in nqdata.columns]
nqdata
# Out:
#                               Close      High       Low      Open  Volume
# Datetime
# 2025-03-10 04:00:00+00:00  20129.50  20129.50  20121.25  20126.50       0
# 2025-03-10 04:01:00+00:00  20128.00  20130.25  20126.75  20128.75      45
# 2025-03-10 04:02:00+00:00  20128.25  20130.25  20126.00  20127.50      38
# 2025-03-10 04:03:00+00:00  20127.00  20129.75  20127.00  20129.75      19
# 2025-03-10 04:04:00+00:00  20130.00  20130.00  20126.75  20126.75      17
# ...                             ...       ...       ...       ...     ...
# 2025-03-11 03:54:00+00:00  19438.75  19441.00  19436.75  19438.25      24
# 2025-03-11 03:55:00+00:00  19438.00  19439.00  19432.50  19439.00      60
# 2025-03-11 03:56:00+00:00  19437.25  19439.00  19435.50  19438.50      46
# 2025-03-11 03:57:00+00:00  19439.50  19440.00  19435.75  19439.50      44
# 2025-03-11 03:58:00+00:00  19437.25  19439.00  19436.75  19438.50      22
#
# [1361 rows x 5 columns]

# %%
#importing the data
bt1 = Backtest(nqdata, EMACrossoverFuturesStrategy, cash=100000, commission=0.00025, exclusive_orders=True)

stats = bt1.run()
print(stats)
# Out:
# Start                     2025-03-10 04:00...
# End                       2025-03-11 03:58...
# Duration                      0 days 23:58:00
# Exposure Time [%]                    18.95665
# Equity Final [$]                     99353.95
# Equity Peak [$]                  100017.41331
# Commissions [$]                      492.9395
# Return [%]                           -0.64605
# Buy & Hold Return [%]                -3.52046
# Return (Ann.) [%]                   -12.25666
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                            -80.51645
# Sharpe Ratio                              NaN
# Sortino Ratio                         -7.4441
# Calmar Ratio                        -18.31138
# Alpha [%]                            -0.63857
# Beta                                  0.00212
# Max. Drawdown [%]                    -0.66935
# Avg. Drawdown [%]                    -0.14094
# Max. Drawdown Duration        0 days 22:30:00
# Avg. Drawdown Duration        0 days 04:40:00
# # Trades                                   50
# Win Rate [%]                             24.0
# Best Trade [%]                         0.1107
# Worst Trade [%]                      -0.17331
# Avg. Trade [%]                       -0.01562
# Max. Trade Duration           0 days 01:15:00
# Avg. Trade Duration           0 days 00:06:00
# Profit Factor                         0.61153
# Expectancy [%]                        -0.0156
# SQN                                  -1.58004
# Kelly Criterion                      -0.15158
# _strategy                 EMACrossoverFutu...
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# #### The Strategy lost -5.58577%. Which is quite terrible if you consider it only ran for one day and had a quite small tp and sl. What we can do is see how we should change the Target and stop loss for optimal results, which is pretty cool.

# %%
# %pip install sambo
# Out:
# Requirement already satisfied: sambo in /opt/anaconda3/envs/algvenv/lib/python3.11/site-packages (1.25.1)
# Requirement already satisfied: numpy>=1.10.0 in /opt/anaconda3/envs/algvenv/lib/python3.11/site-packages (from sambo) (2.2.4)
# Requirement already satisfied: scipy>=1.11.0 in /opt/anaconda3/envs/algvenv/lib/python3.11/site-packages (from sambo) (1.15.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
bt1 = Backtest(nqdata, EMACrossoverFuturesStrategy, cash=100_000, commission=0.00025, exclusive_orders=True)

best_result, opt_result = bt.optimize(
    point_tp=range(10, 40, 5),
    point_sl=range(5, 25, 5),
    short_period=range(8, 20, 2),
    long_period=range(20, 50, 5),
    constraint=lambda p: p.point_tp > p.point_sl and p.short_period < p.long_period,
    maximize='Equity Final [$]',
    method='sambo',
    return_optimization=True
)

#Convert OptimizeResult to DataFrame
param_names = ['point_tp', 'point_sl', 'short_period', 'long_period']
param_values = opt_result.xv
equity_final = [-v for v in opt_result.funv]  #negate for maximization

results_df = pd.DataFrame(param_values, columns=param_names)
results_df['Equity Final [$]'] = equity_final

#Preview
results_df.head()
# Out:
#   point_tp point_sl short_period long_period  Equity Final [$]
# 0       27       20           16          45      99184.487562
# 1       27       20           16          45      99794.632500
# 2       27       20           16          45      99702.199625
# 3       26       20           16          45      99616.651875
# 4       26       20           16          45      99635.973500

# %% [markdown]
# #### Now with the use of Optimize and Sambo, we have a dataframe containing the Equity Results for all of the different combinations we put into Optimize. Of course Equity Final means nothing in this short of a backtest. But its a introduction to visualizing the results through heatmap

# %%
tp_vals = range(10, 40, 5)
sl_vals = range(5, 25, 5)
short_vals = [12, 14, 16]
long_vals = [30, 35, 40]

data = []

#Simulating results for every combination of TP, SL, short EMA, long EMA
for short in short_vals:
    for long in long_vals:
        for tp in tp_vals:
            for sl in sl_vals:
                equity = 100000 + np.random.normal(loc=tp - sl + (short - long)/2, scale=20) * 10
                data.append({
                    'point_tp': tp,
                    'point_sl': sl,
                    'short_period': short,
                    'long_period': long,
                    'Equity Final [$]': equity
                })

results_df = pd.DataFrame(data)

# Let's say we want to see TP vs SL for short=14, long=35
filtered = results_df[(results_df.short_period == 14) & (results_df.long_period == 35)]

#Group by TP/SL and get max equity (in case of duplicates)
grouped = filtered.groupby(['point_tp', 'point_sl'])['Equity Final [$]'].max().reset_index()

#Pivot for heatmap
pivot = grouped.pivot(index='point_sl', columns='point_tp', values='Equity Final [$]')

#Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt=".0f", cmap="coolwarm")
plt.title("Equity Final [$] — TP vs SL (Short EMA=14, Long EMA=35)")
plt.ylabel("Stop Loss (points)")
plt.xlabel("Take Profit (points)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Now this was using a set number as the TP and SL. What happens to the strategy if we make it vary with ATR

# %%
class ATREMACrossStrategy(Strategy):
    short_period = 12
    long_period = 26
    atr_sl_mult = 1.0
    atr_tp_mult = 2.0
    atr_period = 14

    def init(self):
        self.short_ema = self.I(talib.EMA, self.data.Close, self.short_period)
        self.long_ema = self.I(talib.EMA, self.data.Close, self.long_period)
        self.atr = self.I(talib.ATR, self.data.High, self.data.Low, self.data.Close, timeperiod=self.atr_period)

    def next(self):
        price = self.data.Close[-1]
        atr_val = self.atr[-1]

        #Using ATR for dynamic SL/TP
        sl_points = atr_val * self.atr_sl_mult
        tp_points = atr_val * self.atr_tp_mult

        crossover_up = self.short_ema[-2] < self.long_ema[-2] and self.short_ema[-1] > self.long_ema[-1]
        crossover_down = self.short_ema[-2] > self.long_ema[-2] and self.short_ema[-1] < self.long_ema[-1]

        try:
            if crossover_up and not self.position.is_long:
                sl = price - sl_points
                tp = price + tp_points
                self.buy(size=1, sl=sl, tp=tp)

            elif crossover_down and not self.position.is_short:
                sl = price + sl_points
                tp = price - tp_points
                self.sell(size=1, sl=sl, tp=tp)
        except:
            pass

# %%
bt2 = Backtest(nqdata, ATREMACrossStrategy, cash=100000, commission=0.00025, exclusive_orders=True)

best_result, opt_result = bt2.optimize(
    atr_tp_mult=[1.0, 1.5, 2.0, 2.5, 3.0],
    atr_sl_mult=[0.5, 1.0, 1.5, 2.0],
    short_period=range(10, 20, 2),
    long_period=range(25, 45, 5),
    constraint=lambda p: p.atr_tp_mult > p.atr_sl_mult and p.short_period < p.long_period,
    maximize='Equity Final [$]',
    method='sambo',
    return_optimization=True
)

best_result
# Out:
# Start                     2025-03-10 04:00...
# End                       2025-03-11 03:58...
# Duration                      0 days 23:58:00
# Exposure Time [%]                    36.00294
# Equity Final [$]                 100203.44551
# Equity Peak [$]                  100205.45558
# Commissions [$]                     356.22237
# Return [%]                            0.20345
# Buy & Hold Return [%]                -3.52046
# Return (Ann.) [%]                     6.69317
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                             67.00845
# Sharpe Ratio                              NaN
# Sortino Ratio                             inf
# Calmar Ratio                          43.6903
# Alpha [%]                             0.15672
# Beta                                 -0.01327
# Max. Drawdown [%]                     -0.1532
# Avg. Drawdown [%]                    -0.02987
# Max. Drawdown Duration        0 days 11:06:00
# Avg. Drawdown Duration        0 days 00:56:00
# # Trades                                   36
# Win Rate [%]                         55.55556
# Best Trade [%]                        0.40882
# Worst Trade [%]                      -0.22353
# Avg. Trade [%]                        0.07932
# Max. Trade Duration           0 days 00:42:00
# Avg. Trade Duration           0 days 00:14:00
# Profit Factor                         3.21965
# Expectancy [%]                        0.07946
# SQN                                   2.76823
# Kelly Criterion                       0.38165
# _strategy                 ATREMACrossStrat...
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
param_names = ['atr_tp_mult', 'atr_sl_mult', 'short_period', 'long_period']
param_values = opt_result.xv
equity_final = [-v for v in opt_result.funv]

results_df = pd.DataFrame(param_values, columns=param_names)
results_df['Equity Final [$]'] = equity_final
#Drop NaNs
clean_df = results_df.dropna(subset=['Equity Final [$]'])

# %%
#Drop NaNs
clean_df = results_df.dropna(subset=['Equity Final [$]'])

clean_df['atr_tp_mult'] = clean_df['atr_tp_mult'].round(.25)  # or .25
clean_df['atr_sl_mult'] = clean_df['atr_sl_mult'].round(.25)

#Group and pivot
grouped = clean_df.groupby(['atr_sl_mult', 'atr_tp_mult'])['Equity Final [$]'].max().reset_index()
pivot = grouped.pivot(index='atr_sl_mult', columns='atr_tp_mult', values='Equity Final [$]')

plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt=".0f", cmap="crest")
plt.title("Equity Final [$] — ATR TP vs SL (Rounded Multipliers)")
plt.ylabel("ATR SL Multiplier")
plt.xlabel("ATR TP Multiplier")
plt.tight_layout()
plt.show()

# %%
best_result
# Out:
# Start                     2025-03-10 04:00...
# End                       2025-03-11 03:58...
# Duration                      0 days 23:58:00
# Exposure Time [%]                    26.74504
# Equity Final [$]                 100166.94157
# Equity Peak [$]                  100166.94157
# Commissions [$]                     277.06325
# Return [%]                            0.16694
# Buy & Hold Return [%]                -3.52405
# Return (Ann.) [%]                     4.34539
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                             52.33725
# Sharpe Ratio                              NaN
# Sortino Ratio                             inf
# Calmar Ratio                         27.76718
# Alpha [%]                             0.13847
# Beta                                 -0.00808
# Max. Drawdown [%]                    -0.15649
# Avg. Drawdown [%]                    -0.02482
# Max. Drawdown Duration        0 days 08:21:00
# Avg. Drawdown Duration        0 days 01:07:00
# # Trades                                   28
# Win Rate [%]                         60.71429
# Best Trade [%]                        0.41096
# Worst Trade [%]                      -0.22514
# Avg. Trade [%]                        0.08006
# Max. Trade Duration           0 days 00:53:00
# Avg. Trade Duration           0 days 00:13:00
# Profit Factor                         2.90061
# Expectancy [%]                        0.08021
# SQN                                   2.40057
# Kelly Criterion                       0.39644
# _strategy                 ATREMACrossStrat...
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
